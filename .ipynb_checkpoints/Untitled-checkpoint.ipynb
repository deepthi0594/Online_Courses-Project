# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)

# %%
data=pd.read_csv('udemy_and_edx_courses.csv')
data
# Out:
#                                                     url  \
# 0     https://www.udemy.com/drawing-and-sketching-fo...
# 1     https://www.edx.org/course/inteligencia-emocio...
# 2     https://www.edx.org/course/entrepreneurship-in...
# 3     https://www.udemy.com/hands-on-guitar-beyond-b...
# 4        https://www.udemy.com/using-modern-javascript/
# ...                                                 ...
# 3111  https://www.udemy.com/finance-and-accounting-f...
# 3112   https://www.udemy.com/trumpet-a-beginners-guide/
# 3113  https://www.udemy.com/straight-from-business-s...
# 3114  https://www.edx.org/course/favoriser-le-bien-e...
# 3115  https://www.udemy.com/instant-bodhran-part-two...
#
#                                                   title               subject  \
# 0     How to Draw and Sketch for Absolute Beginners ...                Design
# 1     AnahuacX: Inteligencia emocional para el lider...       Social Sciences
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3116 entries, 0 to 3115
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   url                3116 non-null   object
#  1   title              3116 non-null   object
#  2   subject            3116 non-null   object
#  3   level              3116 non-null   object
#  4   total_length       3116 non-null   float64
#  5   rating             3116 non-null   float64
#  6   num_ratings        3116 non-null   float64
#  7   price              3116 non-null   float64
#  8   num_students       3116 non-null   float64
#  9   past_num_students  3116 non-null   float64
#  10  online_academy     3116 non-null   object
# dtypes: float64(6), object(5)
# memory usage: 267.9+ KB

# %%
try_1=pd.DataFrame(data['online_academy'].value_counts(dropna=False))

# %%
try_1.index.values.tolist()
# Out:
# ['Udemy', 'edX']

# %%
import sklearn

# %%
sklearn.__version__
# Out:
# '1.2.2'
